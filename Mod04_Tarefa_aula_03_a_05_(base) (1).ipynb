# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
mat=	24
por=	18
geo=	8
ing=	8
his=	8
fi =   12
qui =	12

def values(df,cond, nome=str):
    soma_acerto = df["Qt_acertos"].sum()
    soma2 = (soma_acerto / (len(df) * cond)) * 100
    return print(nome,soma2)



values(df_mat, mat, "mate")
values(df_por,por, "portu")
values(df_geo,geo, "geog")
values(df_ing,ing, "ingle")
values(df_his, his, "histo")
values(df_fis,fi, "fisic")
values(df_qui,qui, "quim")
# Out:
# mate 49.375
# portu 40.166666666666664
# geog 42.0
# ingle 47.625
# histo 45.0
# fisic 44.333333333333336
# quim 45.25

# %%
# 2) Seu código aqui

#(operações entre *DataFrames) Calcule o total de acertos de cada aluno.)

def acertos(df):
    return df["Qt_acertos"].tolist()

acerto_geral= []
listM = acertos(df_mat)
listP = acertos(df_fis)
listG = acertos(df_geo)
listI = acertos(df_ing)
listH = acertos(df_his)
listF = acertos(df_fis)
listQ = acertos(df_qui)

for i in range(len(listM)):   
    acerto_geral.append(listM[i] + listP[i] +listG[i] + listI[i] +listH[i] +listF[i]+ listQ[i])
    
    #vou somar geral aq é isso.
    
print(re)
print(len(re))
# Out:
# [36, 49, 38, 25, 37, 57, 29, 46, 54, 41, 30, 41, 34, 20, 24, 44, 36, 39, 57, 44, 44, 33, 29, 34, 59, 27, 26, 40, 41, 55, 41, 50, 30, 37, 34, 34, 51, 46, 39, 42, 49, 37, 45, 15, 32, 47, 40, 26, 58, 18, 41, 34, 39, 41, 32, 32, 33, 51, 37, 31, 47, 40, 41, 26, 42, 16, 27, 48, 44, 32, 59, 47, 34, 21, 35, 45, 44, 62, 61, 30, 31, 40, 29, 47, 25, 42, 40, 45, 58, 61, 27, 26, 38, 46, 23, 39, 30, 36, 40, 34, 36, 49, 38, 25, 37, 57, 29, 46, 54, 41, 30, 41, 34, 20, 24, 44, 36, 39, 57, 44, 44, 33, 29, 34, 59, 27, 26, 40, 41, 55, 41, 50, 30, 37, 34, 34, 51, 46, 39, 42, 49, 37, 45, 15, 32, 47, 40, 26, 58, 18, 41, 34, 39, 41, 32, 32, 33, 51, 37, 31, 47, 40, 41, 26, 42, 16, 27, 48, 44, 32, 59, 47, 34, 21, 35, 45, 44, 62, 61, 30, 31, 40, 29, 47, 25, 42, 40, 45, 58, 61, 27, 26, 38, 46, 23, 39, 30, 36, 40, 34]
# 200

# %%
# 3) Seu código aqui
#Calcule o porcentual geral de cada aluno.
for i in acerto_geral:
    porcen = round((i / 90) * 100,1)
    print("soma total",i,porcen,"%","porcentagem geral")
# Out:
# soma total 36 40.0 % porcentagem total
# soma total 49 54.4 % porcentagem total
# soma total 38 42.2 % porcentagem total
# soma total 25 27.8 % porcentagem total
# soma total 37 41.1 % porcentagem total
# soma total 57 63.3 % porcentagem total
# soma total 29 32.2 % porcentagem total
# soma total 46 51.1 % porcentagem total
# soma total 54 60.0 % porcentagem total
# soma total 41 45.6 % porcentagem total
# soma total 30 33.3 % porcentagem total
# soma total 41 45.6 % porcentagem total
# soma total 34 37.8 % porcentagem total
# soma total 20 22.2 % porcentagem total
# soma total 24 26.7 % porcentagem total
# soma total 44 48.9 % porcentagem total
# soma total 36 40.0 % porcentagem total
# soma total 39 43.3 % porcentagem total
# soma total 57 63.3 % porcentagem total
# soma total 44 48.9 % porcentagem total
# soma total 44 48.9 % porcentagem total
# soma total 33 36.7 % porcentagem total
# soma total 29 32.2 % porcentagem total
# soma total 34 37.8 % porcentagem total
# ...

# %%
# 4) Seu código aqui
#Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?
acerto_geral = np.array(acerto_geral)
count = np.sum(acerto_geral > 45)
print(count)
# Out:
# 24

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

desqua= ()

df_total = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df_total.columns = ['matematica', 'portugues', 'geografia', 'ingles', 'historia', 'fisica', 'quimica']
desqua = df_total[(df_total['matematica'] == 0) | (df_total['fisica'] == 0) | (df_total['quimica'] == 0)]
num_desqua = len(desqua)
print(num_desqua)
media_desqua = desqua[["historia","geografia"]].mean()
passaram = df_total[(df_total['matematica'] > 0) & (df_total['fisica'] > 0) & (df_total['quimica'] > 0)]
print(passaram)
# Out:
# 23
#     matematica  portugues  geografia  ingles  historia  fisica  quimica
# 0            6          7          7       3         1       8        3
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 4            7          2          2       7         0       9        3
# 5           20          2          5       3         2       9        9
# ..         ...        ...        ...     ...       ...     ...      ...
# 93          12         16          5       5         6       6        6
# 95           6          4          7       1         4       9        3
# 96           8          1          4       6         1       4        3
# 97          23          5          0       2         4       1        5
# 99          11         15          0       1         6       7        2
#
# [77 rows x 7 columns]

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
# 1) Sua solução aqui
import csv

datv = pd.read_csv('dadosvacina.csv', quoting=csv.QUOTE_NONE, sep=";", quotechar='"')

#tive que adicionar esses "indicadores", o csv estava meio corrompido.

datv.columns = dat.columns.str.replace('"', '')
datcop= datv[:20000].copy()
datcop.head(1)
dvc = datcop['vacina_nome']
dupli = datcop['vacina_nome'].drop_duplicates()
qtd_fabricantes = len(dupli)
print(qtd)
print(dupli)
# Out:
# 12
# 0                        "COVID-19 JANSSEN - Ad26.COV2.S"
# 1                           "COVID-19 PFIZER - COMIRNATY"
# 2                 "COVID-19 SINOVAC/BUTANTAN - CORONAVAC"
# 4             "COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD"
# 8                "COVID-19 PEDIÁTRICA - PFIZER COMIRNATY"
# 15                "COVID-19 PFIZER - COMIRNATY BIVALENTE"
# 42                                                 "INF3"
# 98      "COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR ...
# 122                        "COVID-19 SINOVAC - CORONAVAC"
# 231              "COVID-19 PFIZER - COMIRNATY PEDIÁTRICA"
# 242                    "COVID-19 ASTRAZENECA - ChAdOx1-S"
# 339                         "COVID-19 MODERNA - SPIKEVAX"
# 2507                                   "COVID-19 MODERNA"
# Name: vacina_nome, dtype: object

# %%
# 2)
valor_unico= datcop['paciente_id']
qtd_vacinas = len(valor_unico)
print(soms)
#sinceramente eu nao entendi muito essa pergunta, se ele ta na base, é pq foi vacinado...
# Out:
# 20000

# %%
# 3)Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método  unique

datcop['vacina_descricao_dose']
datcop['cond'] = 0
datcop.loc[datcop['vacina_descricao_dose'] == '"1ª Dose"','cond'] = 1
pacientes_primeira = datcop['cond'].sum()

# %%
# 3) solução alternativa
datcop.head(2)
cot= datcop['vacina_descricao_dose'].value_counts()
quantidade_primeira_dose = cot['"1ª Dose"']
print(quantidade_primeira_dose)
# Out:
# 7368

# %%
# 4)
datcop.head(1)
datcop['paciente_idade'].unique()
datcop['paciente_idade'] = datcop['paciente_idade'].astype(int)
menor = datcop.loc[datcop['paciente_idade'] < 18]
Qtd_menores = len(menor)
print(Qtd_menores)
# Out:
# 4017

# %%
# 5)

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
new_data=datcop.loc[datcop['paciente_idade'] < 18]
new_data.head()
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 2)
colunas = new_data.columns
# Out:
# 4017

# %%
# 3)
new_data['vacina_categoria_nome'].count()
# Out:
# 4017

# %%
# 4)
col = ['estabelecimento_valor','estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
esta = new_data.loc[:, col]

# %%
# 5)
lista_sem_d = esta.drop_duplicates()
lista_final = lista_sem_d.to_dict(orient='records')
print(lista_final)
# Out:
# [{'estabelecimento_valor': '"6917291"', 'estabelecimento_razaoSocial': '"PREFEITURA MUNICIPAL DE RIO BRANCO"', 'estalecimento_noFantasia': '"DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMBIENTAL"', 'estabelecimento_municipio_codigo': '"120040"', 'estabelecimento_municipio_nome': '"RIO BRANCO"', 'estabelecimento_uf': '"AC"'}, {'estabelecimento_valor': '"2001349"', 'estabelecimento_razaoSocial': '"PREFEITURA MUNICIPAL DE BRASILEIA"', 'estalecimento_noFantasia': '"ESF TUFIC MIZAEL SAADY"', 'estabelecimento_municipio_codigo': '"120010"', 'estabelecimento_municipio_nome': '"BRASILEIA"', 'estabelecimento_uf': '"AC"'}, {'estabelecimento_valor': '"7247435"', 'estabelecimento_razaoSocial': '"PREFEITURA MUNICIPAL DE SAUDE"', 'estalecimento_noFantasia': '"UNIDADE DE SAUDE DA FAMILIA RAIMUNDO CELSO LIMA VERDE"', 'estabelecimento_municipio_codigo': '"120020"', 'estabelecimento_municipio_nome': '"CRUZEIRO DO SUL"', 'estabelecimento_uf': '"AC"'}, {'estabelecimento_valor': '"0924490"', 'estabelecime
# ...

# %%
import matplotlib.pyplot as plt
total = len(datcop)
som= total - Qtd_menores
porcentagem_menor= round((Qtd_menores/ total) * 100,1)
porcentagem_rest= round((som/total)* 100,1)
print(porcentagem_menor)
print(porcentagem_rest)

labels =['Menores vacinados', 'Restantes']
sizes= [porcentagem_menor, porcentagem_rest]
colors= ['lightgreen' ,'lightskyblue']
explode=[0.1,0.0]
plt.figure(figsize=(8,6))

plt.pie(sizes, explode=explode, labels=labels,colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('% de Vacinados.')
plt.axis('equal') 
plt.show()
# Out:
# 20.1
# 79.9

# %%
#vacinas mais usadas.
dvc.head()
# Out:
# 0                "JANSSEN"
# 1                 "PFIZER"
# 2       "SINOVAC/BUTANTAN"
# 3                 "PFIZER"
# 4    "ASTRAZENECA/FIOCRUZ"
# Name: vacina_fabricante_nome, dtype: object

# %%
datcop['cond'] = 0
vanome = datcop['vacina_nome'].value_counts()
plt.figure(figsize=(15, 10)) 
vanome.plot(kind='bar', color='skyblue')
print(vanome)

plt.title('Contagem de Vacinas Usadas', fontsize=16)
plt.xlabel('Vacinas', fontsize=12)
plt.ylabel('Quantidade Usada', fontsize=12)

for index, value in enumerate(vanome):
    plt.text(index, value, str(value), ha='center', va='bottom')

# Exibir o gráfico
plt.xticks(rotation=45)
plt.tight_layout()  # Ajusta o layout
plt.show()
# Out:
# vacina_nome
# "COVID-19 PFIZER - COMIRNATY"                               7739
# "COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD"                 5531
# "COVID-19 SINOVAC/BUTANTAN - CORONAVAC"                     2730
# "INF3"                                                      1053
# "COVID-19 PFIZER - COMIRNATY BIVALENTE"                      827
# "COVID-19 JANSSEN - Ad26.COV2.S"                             699
# "COVID-19 PEDIÁTRICA - PFIZER COMIRNATY"                     641
# "COVID-19 ASTRAZENECA - ChAdOx1-S"                           281
# "COVID-19 PFIZER - COMIRNATY PEDIÁTRICA"                     184
# "COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS"     168
# "COVID-19 SINOVAC - CORONAVAC"                                69
# "COVID-19 MODERNA - SPIKEVAX"                                 47
# "COVID-19 MODERNA"                                            31
# Name: count, dtype: int64

# %%
#analise:
#segundo os graficos a maior parte da populaçao a ser vacinada esta acima de 18 anos, isso demonstra que devemos aumentar a campanha para jovens se vacinar.
#graficos de barra mostram as vacinas mais usadas.
