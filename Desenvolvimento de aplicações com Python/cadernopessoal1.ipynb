# %%
# este caderno é pessoal

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("demo01.csv")

df = pd.DataFrame(df)
df['indi'] = ['gay'] * 16650 #add coluna
df = df.rename(columns={'sexo': 'genero'}) #mudando nome da coluna 

df.head()
# Out:
#   genero posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0      M                Y               Y           0               Working
# 1      F                N               Y           0  Commercial associate
# 2      F                N               Y           0  Commercial associate
# 3      M                Y               Y           0               Working
# 4      F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
# ...

# %% [markdown]
# # Aula sobre matplotlib quando tiver dificuldade com graficos venha aqui(bem vindo de voltakk)

# %%
# isso é um comando do propio jupyter not
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = [1,2,3,3,2,3,4,5]

plt.plot(data)

#acabou de criar um grafico padrao de plot, com o "dataframe"

# %%
#aqui ele cria uma figura.
fig = plt.figure()
#aqui ele adiciona um subplot oq é?
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
#resposta de cima, esse 2,2,1 sao as dimensoes da imagem.
#vai ficar numa estrutura com 2 linhas 2 colunas e ele vai preecher a posicçao um
plt.plot(np.random.randn(50).cumsum(), 'k--')
#pq ele adicionou apenas no ultimo? pq foi o ultimo a ser lançado.
# da um shift tab ele te mostra mais sobre essa funçao "k--" etc.
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.3)
#alpha é um vetor de transparencia, quanto mais numeraçao, mais transparente.
_ = ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
#esse hist é um tipo de grafico e esse scatter tbm. o ax1 e ax2 sao os graficos que vao ocupar.
fig = plt.figure()

# %%
#configura as linhas "K" é uma cor e "--" é um tipo de linha.
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=.3)
_ = ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

fig = plt.figure()

# %%
fig, axes = plt.subplots(2, 3)
# esse fig recebe aquela figurinha que a gente criou e o axes sao os eixos que vao ser dados dentro do () ou seja 2 linhas e 3 colunas.ou seja 6 graficos

axes.shape 
#mostra como ta o bagulho 
axes[0,0]
#esse comando seleciona qual grafico vc quer, nesse caso o 0 0 seria o primeiro ou seja o primeiro da sua esquerda no angulo de cima.
# Out:
# (2, 3)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
#isso é criaçao de coisa p botar no grafico.
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='b', alpha=0.9)
        
# O método subplots_adjust ajusta o espaçamento entre os eixos.
plt.subplots_adjust(wspace=0, hspace=0)

#esse subplost adjust é o espaço entre os graficos, desse modo zerado ele literalmente fica colado um no outro 


# Cores, marcadores e estilo de linha 
#ax.plot(x, y, 'g--')
#ou seja, uma forma mais simples e outra mais amostral digamos assim.
#ax.plot(x, y, linestyle='--', color='g')

# %%
data = np.random.randn(30).cumsum()
#como visto acima, aqui esta a configuraçao dos graficos como linha etc roda e ve como funfa
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'b-', drawstyle='steps-post', label='steps-post')
#esse loc diz a melhor posiçao pra botar o bag 
plt.legend(loc='best')

# %%
# tiques rotulos e legenda.

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
#metodo ticks do objeto ax(matrizes que estamos usando , esses numeros de 0 a 1000 é onde vao ser colocado os nomes ou indices chame como for no caso esse ano1 ano2 etc.
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
#ou seja, escolheu a posiçao com ticks
#e editou com o metodo xticklabels sendo botado dentro da variavel label. com rotaçao em 30 e font pequena(small)
labels = ax.set_xticklabels(['ano 1', 'ano 2', 'ano 3', 'ano 4', 'ano 5'],
                            rotation=30, fontsize='small')

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['ano 1', 'ano 2', 'ano 3', 'ano 4', 'ano 5'],
                            rotation=30, fontsize='small')

# %%
ax.set_title('Título do gráfico')
ax.set_xlabel('Período')
#inserindo titulo no grafico etc.
# Out:
# Text(0.5, 4.444444444444445, 'Período')

# %% [markdown]
# plt.close('all')
# from numpy.random import randn
# fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
# ax.plot(randn(1000).cumsum(), 'k--', label='two')
# ax.plot(randn(1000).cumsum(), 'k.', label='three')
#
# ax.legend(loc='best')
# #plt.savefig('figura.jpg')
# #salvando em um jpn ou png sla

# %% [markdown]
# # Criando graficos basicos

# %%
import seaborn as sns#to so importando o seaborn pq ja importei o resto 
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
#esse tips do sns ja é algo que vem junto cm ele, ou seja nesse trecho de codigo estamos criando um "dataframe" 
#nao vamos usar isso agora, isso é pra mais tarde.
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069

# %%
df = pd.DataFrame({'col1':[10, 20, 30]}, index = [1, 2, 3])
df
#criando um dataframe aleatorio.
df.plot.bar()
#grafico simples de barra.
# Em geral precisamos trabalhar a base para fazer o gráfico
#tips é a base, dia é a coluna, valuecounts é a contagem, sort_index é para organizar os valores em ordem e plot e bar é configuraçao de barra.
tips['day'].value_counts().sort_index().plot.bar()

# O Seaborn já faz essa manipulação pra nós, ele fez isso tudo, em uma linha menor, e so precisamos passar a base
sns.countplot(x='day', data=tips)

# Os gráficos funcionam dentro da lógica do matplotlib
plt.close('all')
plt.rc('figure', figsize=(10, 8))
fig, axes = plt.subplots(2, 2)

sns.countplot(ax = axes[0, 0], x='day', data=tips)
sns.countplot(ax = axes[0, 1], x='sex', data=tips)
sns.countplot(ax = axes[1, 0], x='smoker', data=tips)
sns.countplot(ax = axes[1, 1], x='time', data=tips)

# %%
# Você pode também usar o barplot que traz a média da variável y por padrão
plt.close('all')
plt.rc('figure', figsize=(10, 8))
fig, axes = plt.subplots(2, 2)

sns.countplot(ax = axes[0,0], x='day',data=tips)
sns.barplot(ax = axes[0, 1], x='day', y='tip_pct', data=tips)
sns.barplot(ax = axes[1, 0], x='day', y='tip', data=tips)
sns.barplot(ax = axes[1, 1], x='day', y='tip', estimator=sum, data=tips, ci = None)

tips['day'].value_counts().plot.pie()
#grafico pizza
# Out:
# C:\Users\gerar\AppData\Local\Temp\ipykernel_9484\3673437042.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(ax = axes[1, 1], x='day', y='tip', estimator=sum, data=tips, ci = None)
# <Axes: xlabel='day', ylabel='count'>

# %%
# Gráfico de Pareto
from matplotlib.ticker import PercentFormatter

df = pd.DataFrame({'contagem': [43, 20, 174, 5, 2, 1, 1, 0]})
df.index = ['Produto com defeito', 'Produto errado', 'Tempo de entrega', 
            'Horário de entrega', 'Mau atendimento', 'Valor errado', 'Não serve', 'Desistência']

df = df.sort_values(by='contagem',ascending=False)
df["pctacum"] = df["contagem"].cumsum()/df["contagem"].sum()*100

df
fig, ax = plt.subplots()

ax.bar(df.index, df["contagem"])
ax2 = ax.twinx()
ax2.plot(df.index, df["pctacum"], color="r", marker="o")
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="x", rotation = 30)
ax2.tick_params(axis="y", colors="r")
plt.show()

# %% [markdown]
# # VARIAVEIS UNIVARIADAS CONTINUAS

# %%
#NAO IMPORTEI PQ JA IMPORTEI NO INICIO DO CADERNO.
#carregando base de dados abaixo.
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()

tips.describe()
#uma funçao que te devolve umas somas e umas "analises"
# Out:
#        total_bill         tip        size     tip_pct
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672    0.202123
# std      8.902412    1.383638    0.951100    0.163385
# min      3.070000    1.000000    1.000000    0.036955
# 25%     13.347500    2.000000    2.000000    0.148274
# 50%     17.795000    2.900000    2.000000    0.183110
# 75%     24.127500    3.562500    3.000000    0.236821
# max     50.810000   10.000000    6.000000    2.452381

# %%
tips['tip_pct'].plot.hist(bins = 80)

#criando grafico "hist", esse bins 20 sao as quebbras.
# Out:
# <Axes: ylabel='Frequency'>

# %%
tips[tips['tip_pct']>.5]
#criando uma lista somente com as gorjetas acima de 0.5
sns.displot(data = tips[tips['tip_pct']<1] 
            ,alpha = .25
            ,x = 'tip_pct'
            ,bins = 20
            ,element = 'step'
            ,kde = True
           )
#kde é a linha
#emelent deixa o grafico sem linhas.
#esse sns é o seaborn, e ele tem a funçao displot, o data ali ja ta filtrado. alpha é transaparencia, x é da base, bins é o "fatiamento" e os outros sao elementos graficos

# %%
tips[['total_bill']].boxplot( y=') #nao esquece do hue.
#bloxplot com pandas
# Out:
# <Axes: >

# %%
sns.boxplot(y="total_bill", data=tips[tips['tip_pct']<1])
#blox plot com seaborn
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# # fazendo outro tipos de graficos aula depois do 2 exercicio.

# %%
#esse axis dnv ele é o eixo da coluna
#exemplo>
#se eu quero somar as linhas eu boto AXIS=1 tlg?
#vou fazer um resumo dos codigos.
# Out:
#   Cell In[82], line 1
#     esse axis dnv ele é o eixo da coluna
#          ^
# SyntaxError: invalid syntax

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
#criando dataframe

# %%
sns.countplot(x='day'
              , hue = 'smoker'
              , data=tips[tips.tip_pct < 1]
             )

#primeiro grafico.
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
freq = pd.crosstab(tips['smoker'], tips['day'])
freq
#frequencia. 
freq.sum(axis = 1)
freq_pctlin = freq.div(freq.sum(axis = 1), axis = 0)
#somando e construindo um 100 pra gerar a %
freq_pctlin
# Out:
# day         Thur      Fri       Sat       Sun
# smoker
# Yes     0.182796  0.16129  0.451613  0.204301
# No      0.298013  0.02649  0.298013  0.377483

# %%
freq_pctlin.plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
#grafico em cima do dado.
freq = pd.crosstab(tips['day'], tips['smoker'])
print(freq)
print(freq.sum(1))

freq_pctlin = freq.div(freq.sum(axis = 1), axis = 0)
print(freq_pctlin)

freq_pctlin.plot.bar()
# Out:
# smoker  Yes  No
# day
# Thur     17  45
# Fri      15   4
# Sat      42  45
# Sun      19  57
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# dtype: int64
# smoker       Yes        No
# day
# Thur    0.274194  0.725806
# Fri     0.789474  0.210526
# Sat     0.482759  0.517241
# Sun     0.250000  0.750000
# <Axes: xlabel='day'>

# %%
#mais graficos.]
sns.catplot(x='day', y='total_bill'
            , hue = 'smoker'
            , kind='bar'
            , estimator = sum
            , data=tips[tips.tip_pct < 1]
            , ci = None
           )
# Out:
# C:\Users\gerar\AppData\Local\Temp\ipykernel_9484\1644680451.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x='day', y='total_bill'

# %% [markdown]
# # mais graficos,
# # Fazendo uma grade de gráficos
# sns.catplot(x='day', y='tip_pct'
#             , row='time'
#             , col='smoker'
#             , hue = 'sex'
#             , kind='bar'
#             , data=tips[tips.tip_pct < 1]
#            )

# %% [markdown]
# # provavel que vc va usar isso em muita coisa, é uma linha de codigo que faz a porcentagem por numero de apgar5 por tempo de gestacao, entao isso pode ser adicionado em varias outros tipos de casos

# %%
perl = tabelacru.div(tabelacru.sum(axis=1), axis=0) * 100

perl.sum(axis=1)
